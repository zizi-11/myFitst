# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# approved
import kagglehub
import os 

# Download latest version
path = kagglehub.dataset_download("ibriiee/video-games-sales-dataset-2022-updated-extra-feat") # name of the folder 

file_path = os.path.join(path, 'Video_Games.csv') # name of the file
df = pd.read_csv(file_path)

df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#df.head()

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
imputer = SimpleImputer(strategy='mean')
df['Year_of_Release'] = imputer.fit_transform(df[['Year_of_Release']])
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release       0
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df["Year_of_Release"]= df["Year_of_Release"].astype(int)

# %%
df["Year_of_Release"]= df["Year_of_Release"].astype(str)

# %%
df['Genre'] = df['Genre'].fillna('Unknown')
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii            2006        Sports
# 1                  Super Mario Bros.      NES            1985      Platform
# 2                     Mario Kart Wii      Wii            2008        Racing
# 3                  Wii Sports Resort      Wii            2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB            1996  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3            2016        Action
# 16715               LMA Manager 2007     X360            2006        Sports
# 16716        Haitaka no Psychedelica      PSV            2016     Adventure
# 16717               Spirits & Spells      GBA            2003      Platform
# 16718            Winning Post 8 2016      PSV            2016    Simulation
#
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df['Name'] = df['Name'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df['Publisher'] = df['Publisher'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#from sklearn.impute import SimpleImputer

# %%
#pip install scikit-learn

# %%
df['User_Score'] = df['User_Score'].replace('tbd', pd.NA)

# %%
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

# %%
average_score = df['User_Score'].mean()
df['User_Score'] = df['User_Score'].fillna(average_score)

# %%
df['User_Score'] = df['User_Score'].round(2)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score            0
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df['User_Count'] = df['User_Count'].replace('tbd', pd.NA)

# %%
df['User_Count'] = pd.to_numeric(df['User_Count'], errors='coerce')

# %%
average_count = df['User_Count'].mean()
df['User_Count'] = df['User_Count'].fillna(average_count)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score            0
# User_Count            0
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df['User_Count'] = df['User_Count'].astype(int)

# %%
df['Developer'] = df['Developer'].fillna('Unknown')

# %%
most_frequent_rating = df['Rating'].mode()[0]
df['Rating'] = df['Rating'].fillna(most_frequent_rating)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score            0
# User_Count            0
# Developer             0
# Rating                0
# dtype: int64

# %%
df['Rating'] = df['Rating'].fillna(method='ffill')
# Out:
# C:\Users\USER PC\AppData\Local\Temp\ipykernel_27724\4078210177.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Rating'] = df['Rating'].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score            0
# User_Count            0
# Developer             0
# Rating                0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')
df['Critic_Score'] = imputer.fit_transform(df[['Critic_Score']])
df['Critic_Score'] = df['Critic_Score'].round(2)

# %%
df['Critic_Count'] = imputer.fit_transform(df[['Critic_Count']])
df['Critic_Count'] = df['Critic_Count'].round(0)
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii            2006        Sports
# 1                  Super Mario Bros.      NES            1985      Platform
# 2                     Mario Kart Wii      Wii            2008        Racing
# 3                  Wii Sports Resort      Wii            2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB            1996  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3            2016        Action
# 16715               LMA Manager 2007     X360            2006        Sports
# 16716        Haitaka no Psychedelica      PSV            2016     Adventure
# 16717               Spirits & Spells      GBA            2003      Platform
# 16718            Winning Post 8 2016      PSV            2016    Simulation
#
# ...

# %%
df.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  object
#  3   Genre            16719 non-null  object
#  4   Publisher        16719 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     16719 non-null  float64
#  11  Critic_Count     16719 non-null  float64
#  12  User_Score       16719 non-null  float64
#  13  User_Count       16719 non-null  int64
#  14  Developer        16719 non-null  object
#  15  Rating           16719 non-null  object
# ...

# %%
#to display the first 10 rows
df.head(10)
# Out:
#                         Name Platform Year_of_Release         Genre Publisher  \
# 0                 Wii Sports      Wii            2006        Sports  Nintendo
# 1          Super Mario Bros.      NES            1985      Platform  Nintendo
# 2             Mario Kart Wii      Wii            2008        Racing  Nintendo
# 3          Wii Sports Resort      Wii            2009        Sports  Nintendo
# 4   Pokemon Red/Pokemon Blue       GB            1996  Role-Playing  Nintendo
# 5                     Tetris       GB            1989        Puzzle  Nintendo
# 6      New Super Mario Bros.       DS            2006      Platform  Nintendo
# 7                   Wii Play      Wii            2006          Misc  Nintendo
# 8  New Super Mario Bros. Wii      Wii            2009      Platform  Nintendo
# 9                  Duck Hunt      NES            1984       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# ...

# %%
# to show the dataset information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  object
#  3   Genre            16719 non-null  object
#  4   Publisher        16719 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     16719 non-null  float64
#  11  Critic_Count     16719 non-null  float64
#  12  User_Score       16719 non-null  float64
#  13  User_Count       16719 non-null  int64
#  14  Developer        16719 non-null  object
#  15  Rating           16719 non-null  object
# ...

# %%
# describe the statistics of the dataset
df.describe()
# Out:
#            NA_Sales      EU_Sales      JP_Sales   Other_Sales  Global_Sales  \
# count  16719.000000  16719.000000  16719.000000  16719.000000  16719.000000
# mean       0.263330      0.145025      0.077602      0.047332      0.533543
# std        0.813514      0.503283      0.308818      0.186710      1.547935
# min        0.000000      0.000000      0.000000      0.000000      0.010000
# 25%        0.000000      0.000000      0.000000      0.000000      0.060000
# 50%        0.080000      0.020000      0.000000      0.010000      0.170000
# 75%        0.240000      0.110000      0.040000      0.030000      0.470000
# max       41.360000     28.960000     10.220000     10.570000     82.530000
#
#        Critic_Score  Critic_Count    User_Score    User_Count
# count  16719.000000  16719.000000  16719.000000  16719.000000
# mean      68.968870     26.175609      7.127751    162.104372
# std        9.723417     13.242230      1.010635    378.165150
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns  #count unique values in all columns at once 
for col in categorical_cols:
    print(f"{col}:")
    print(df[col].value_counts())
    print()
# Out:
# Name:
# Name
# Need for Speed: Most Wanted      12
# Ratatouille                       9
# LEGO Marvel Super Heroes          9
# Madden NFL 07                     9
# FIFA 14                           9
#                                  ..
# Outdoors Unleashed: Africa 3D     1
# Real Rode                         1
# PGA European Tour                 1
# Duck Hunt                         1
# New Super Mario Bros. Wii         1
# Name: count, Length: 11563, dtype: int64
#
# Platform:
# Platform
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64
#
# ...

# %%
df[["NA_Sales","EU_Sales","JP_Sales","Global_Sales","Other_Sales","Critic_Score","Critic_Count","User_Score" ]].max()  #Maximum game sold in North America
# Out:
# NA_Sales         41.36
# EU_Sales         28.96
# JP_Sales         10.22
# Global_Sales     82.53
# Other_Sales      10.57
# Critic_Score     98.00
# Critic_Count    113.00
# User_Score        9.70
# dtype: float64

# %%
df[["NA_Sales","EU_Sales","JP_Sales","Global_Sales","Other_Sales","Critic_Score","Critic_Count","User_Score" ]].min() 
# the result shows that there are some games didn't have any profit in North America at all
# Out:
# NA_Sales         0.00
# EU_Sales         0.00
# JP_Sales         0.00
# Global_Sales     0.01
# Other_Sales      0.00
# Critic_Score    13.00
# Critic_Count     3.00
# User_Score       0.00
# dtype: float64

# %%
df[["NA_Sales","EU_Sales","JP_Sales","Global_Sales","Other_Sales","Critic_Score","Critic_Count","User_Score" ]].mean()
# Out:
# NA_Sales         0.263330
# EU_Sales         0.145025
# JP_Sales         0.077602
# Global_Sales     0.533543
# Other_Sales      0.047332
# Critic_Score    68.968870
# Critic_Count    26.175609
# User_Score       7.127751
# dtype: float64

# %%
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii            2006        Sports
# 1                  Super Mario Bros.      NES            1985      Platform
# 2                     Mario Kart Wii      Wii            2008        Racing
# 3                  Wii Sports Resort      Wii            2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB            1996  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3            2016        Action
# 16715               LMA Manager 2007     X360            2006        Sports
# 16716        Haitaka no Psychedelica      PSV            2016     Adventure
# 16717               Spirits & Spells      GBA            2003      Platform
# 16718            Winning Post 8 2016      PSV            2016    Simulation
#
# ...

# %%
df.loc[(df["Year_of_Release"] == "2000") | (df["Year_of_Release"] == "2002") ]
# Out:
#                                           Name Platform Year_of_Release  \
# 24                 Grand Theft Auto: Vice City      PS2            2002
# 25               Pokemon Ruby/Pokemon Sapphire      GBA            2002
# 114                  Medal of Honor: Frontline      PS2            2002
# 132                             Kingdom Hearts      PS2            2002
# 133                    Pokémon Crystal Version       GB            2000
# ...                                        ...      ...             ...
# 16628                         Crossroad Crisis       PS            2000
# 16673  Super Robot Taisen: Original Generation      GBA            2002
# 16677           Mortal Kombat: Deadly Alliance      GBA            2002
# 16697                        PGA European Tour      N64            2000
# 16712       Woody Woodpecker in Crazy Castle 5      GBA            2002
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df[df["Genre"].isin(["Sports", "Role-Playing", "Simulation","Fighting"])]
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 10                                            Nintendogs       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...                                                  ...      ...
# 16704                           Mezase!! Tsuri Master DS       DS
# 16705  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16708                                           Plushees       DS
# 16715                                   LMA Manager 2007     X360
# 16718                                Winning Post 8 2016      PSV
#
#       Year_of_Release         Genre           Publisher  NA_Sales  EU_Sales  \
# 0                2006        Sports            Nintendo     41.36     28.96
# ...

# %%
df[df["Global_Sales"].between(35.0,80.0 ,inclusive ="both")]
# Out:
#                 Name Platform Year_of_Release     Genre Publisher  NA_Sales  \
# 1  Super Mario Bros.      NES            1985  Platform  Nintendo     29.08
# 2     Mario Kart Wii      Wii            2008    Racing  Nintendo     15.68
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 1      3.58      6.81         0.77         40.24         68.97          26.0
# 2     12.76      3.79         3.29         35.52         82.00          73.0
#
#    User_Score  User_Count Developer Rating
# 1        7.13         162   Unknown      E
# 2        8.30         709  Nintendo      E

# %%
# global sales that between 30 and 70
df[(df["Global_Sales"] >= 30.0) & (df["Global_Sales"] <= 70.0)]
# Out:
#                        Name Platform Year_of_Release         Genre Publisher  \
# 1         Super Mario Bros.      NES            1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii            2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii            2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB            1996  Role-Playing  Nintendo
# 5                    Tetris       GB            1989        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1     29.08      3.58      6.81         0.77         40.24         68.97
# 2     15.68     12.76      3.79         3.29         35.52         82.00
# 3     15.61     10.93      3.28         2.95         32.77         80.00
# 4     11.27      8.89     10.22         1.00         31.37         68.97
# 5     23.20      2.26      4.22         0.58         30.26         68.97
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.groupby("Platform")["Year_of_Release"].max()
# Out:
# Platform
# 2600    2006
# 3DO     1995
# 3DS     2016
# DC      2008
# DS      2020
# GB      2006
# GBA     2007
# GC      2007
# GEN     1994
# GG      1992
# N64     2006
# NES     1994
# NG      1996
# PC      2016
# PCFX    1996
# PS      2006
# PS2     2011
# PS3     2016
# PS4     2017
# PSP     2015
# PSV     2017
# SAT     1999
# SCD     1994
# SNES    1999
# TG16    1995
# WS      2001
# Wii     2016
# WiiU    2016
# X360    2016
# XB      2008
# XOne    2016
# Name: Year_of_Release, dtype: object

# %%
df["Platform"].value_counts()
# Out:
# Platform
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
# add a column contain the average  of all Seles
df["Average Seles"] = df[["NA_Sales","EU_Sales","JP_Sales","Other_Sales"]].mean(axis =1)
df
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii            2006        Sports
# 1                  Super Mario Bros.      NES            1985      Platform
# 2                     Mario Kart Wii      Wii            2008        Racing
# 3                  Wii Sports Resort      Wii            2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB            1996  Role-Playing
# ...                              ...      ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3            2016        Action
# 16715               LMA Manager 2007     X360            2006        Sports
# 16716        Haitaka no Psychedelica      PSV            2016     Adventure
# 16717               Spirits & Spells      GBA            2003      Platform
# 16718            Winning Post 8 2016      PSV            2016    Simulation
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# line plot of global sales over the years
df.groupby('Year_of_Release')['Global_Sales'].sum().plot(kind='line', marker='o')
plt.title('Global Game Sales Trend Over the Years')
plt.xlabel('Year_of_Release')
plt.ylabel('Total Global Sales (millions)')
plt.show()

# %%
#Bar plot for total sales of a region genre
region_genre = df.groupby('Genre')[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()
region_genre.plot(kind='bar', stacked=True, figsize=(10,6)) 
plt.title('Regional Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Total Sales (millions)')
plt.xticks(rotation=45)
plt.show()
#kind='bar' → tells pandas to make a bar 
#plot.stacked=True → makes the bars stacked, so each region’s sales are stacked on top of each other within the same genre,
#figsize=(10,6) → controls the size of the figure (width = 10, height = 6 inches).

# %%
df['Year_of_Release'] = df['Year_of_Release'].astype(int)
df = df.sort_values(by='Year_of_Release')
plt.figure(figsize=(10,6))
sns.histplot(df['Year_of_Release'], bins=len(df['Year_of_Release'].unique()), kde=False, color='green')
plt.title('Number of Games Released per Year')
plt.xlabel('Year of Release')
plt.ylabel('Number of Games')
plt.xticks(sorted(df['Year_of_Release'].unique()), rotation=45)  # ترتيب وعرض السنوات بشكل مائل
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 4
#       2 df = df.sort_values(by='Year_of_Release')
#       3 plt.figure(figsize=(10,6))
# ----> 4 sns.histplot(df['Year_of_Release'], bins=len(df['Year_of_Release'].unique()), kde=False, color='green')
#       5 plt.title('Number of Games Released per Year')
#       6 plt.xlabel('Year of Release')
#
# NameError: name 'sns' is not defined

# %%
genre_sales = df.groupby('Genre')['Global_Sales'].sum()
plt.pie(genre_sales, labels=genre_sales.index, autopct='%1.1f%%', startangle=30)
plt.title('Proportion of Global Sales by Genre')
plt.show()

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='Critic_Score', y='Global_Sales', hue='Genre', alpha=0.7)
plt.title('Critic Score vs Global Sales by Genre')
plt.xlabel('Critic Score (0–100)')
plt.ylabel('Global Sales (millions)')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["Platform"], df["Global_Sales"], color='skyblue', alpha=0.6)
plt.title("Platform vs Global Sales")
plt.xlabel("Platform")
plt.ylabel("Global Sales (millions)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Platform', y='Critic_Score')
plt.title('Critic Score Distribution by Platform')
plt.xlabel('Platform')
plt.ylabel('Critic Score (0–100)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# إذا كان الصندوق في المنصة "PS4" أعلى من الصندوق في المنصة "Wii"، فهذا يعني أن ألعاب PS4 غالبًا تقييمها أعلى من ألعاب Wii.
#
# إذا كانت الصناديق طويلة جدًا → يعني أن التقييمات تختلف كثيرًا من لعبة لأخرى (بعضها ممتاز وبعضها ضعيف).
#
# إذا كانت قصيرة → فالتقييمات متقاربة، أي معظم الألعاب في تلك المنصة جودتها متشابهة

# %%
import matplotlib.pyplot as plt

# %%
numeric_cols = ['Critic_Score', 'User_Score', 'Global_Sales', 
                'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']

# %%
corr = df[numeric_cols].corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap between Sales and Review Scores')
plt.show()

# %%
genre_stats = df.groupby('Genre').agg({
    'Global_Sales': 'sum',
    'Critic_Score': 'mean'
}).reset_index()

fig, ax1 = plt.subplots(figsize=(10,6))
#bar plot
ax1.bar(genre_stats['Genre'], genre_stats['Global_Sales'], color='skyblue', label='Global Sales')
ax1.set_xlabel('Genre')
ax1.set_ylabel('Global Sales (millions)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
plt.xticks(rotation=45)

#line plot
ax2 = ax1.twinx()
ax2.plot(genre_stats['Genre'], genre_stats['Critic_Score'], color='red', marker='o', label='Critic Score')
ax2.set_ylabel('Average Critic Score (0–100)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Global Sales and Average Critic Score by Genre')
plt.show()

# %%
df['Score_Diff'] = df['Critic_Score'] - (df['User_Score'] * 10)  # match scale (0–100)
genre_diff = df.groupby('Genre')['Score_Diff'].mean().sort_values(ascending=False)

# %%
plt.figure(figsize=(10,6))
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.title('Critic vs User Agreement by Genre')
plt.xticks(rotation=45)
sns.barplot(y=genre_diff.index, x=genre_diff.values, palette='coolwarm')
plt.xlabel('Average Difference (Critic - User)')
plt.ylabel('Genre')
plt.show()
# Out:
# C:\Users\USER PC\AppData\Local\Temp\ipykernel_27724\877178684.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=genre_diff.index, x=genre_diff.values, palette='coolwarm')

# %% [markdown]
# إذا كانت النتيجة موجبة (+) → يعني أن النقاد أعجبوا باللعبة أكثر من اللاعبين.
#
# إذا كانت سالبة (-) → يعني أن اللاعبين أحبوا اللعبة أكثر من النقاد.
#
# إذا كانت قريبة من الصفر (0) → يعني اتفاق بين الطرفين تقريبًا.

# %%
rating_counts = df['Rating'].value_counts()
df=df.dropna(subset = ['Rating'])
plt.figure(figsize=(8, 6))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=0, colors=plt.cm.Paired.colors)
plt.title('Distribution of Game Ratings')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular
plt.tight_layout()
plt.show()

# %%
df["Rating"].unique()
# Out:
# array(['E', 'T', 'E10+', 'M', 'K-A', 'EC', 'AO', 'RP'], dtype=object)

# %%
# --- 1. Count of Rating Types per Platform ---
plt.figure(figsize=(14, 6))
sns.countplot(data=df, x='Platform', hue='Rating', order=df['Platform'].value_counts().index)
plt.title('Distribution of Game Ratings Across Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)
plt.legend(title='Rating')
plt.tight_layout()
plt.show()

# --- 2. Rating Distribution within a Specific Genre ---
genre_filter = 'Action'  # Change this to any genre you want to explore
df_genre = df[df['Genre'] == genre_filter]

plt.figure(figsize=(8, 5))
sns.countplot(data=df_genre, x='Rating', order=df_genre['Rating'].value_counts().index)
plt.title(f'Game Ratings in {genre_filter} Genre')
plt.xlabel('Rating')
plt.ylabel('Number of Games')
plt.tight_layout()
plt.show()

# %%
# Count ratings
rating_counts = df['Rating'].value_counts()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Game Rating Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular
plt.show()
